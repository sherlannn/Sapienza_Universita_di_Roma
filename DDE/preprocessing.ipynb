# %%
import numpy as np
import pandas as pd

# %%
df2 = pd.read_csv("loan_sanction_test.csv")
df1 = pd.read_csv("loan_sanction_train.csv")

# %%
df1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
len(df1)
# Out:
# 614

# %%
df1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df1['Married'] = df1['Married'].replace({'Yes': 1, 'No': 0})

# %%
df1.head()
# Out:
#     Loan_ID Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      0.0          0      Graduate            No
# 1  LP001003   Male      1.0          1      Graduate            No
# 2  LP001005   Male      1.0          0      Graduate           Yes
# 3  LP001006   Male      1.0          0  Not Graduate            No
# 4  LP001008   Male      0.0          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df1.head()
# Out:
#     Loan_ID Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      0.0          0      Graduate            No
# 1  LP001003   Male      1.0          1      Graduate            No
# 2  LP001005   Male      1.0          0      Graduate           Yes
# 3  LP001006   Male      1.0          0  Not Graduate            No
# 4  LP001008   Male      0.0          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
total_nan = df1.isna().sum().sum()

# %%
print(total_nan)
# Out:
# 149

# %%
mean_column1 = df1['LoanAmount'].mean()

# Fill NaN values in 'column1' with the mean
df1['LoanAmount'] = df1['LoanAmount'].fillna(mean_column1)

# %%
df1.head()
# Out:
#     Loan_ID Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      0.0          0      Graduate            No
# 1  LP001003   Male      1.0          1      Graduate            No
# 2  LP001005   Male      1.0          0      Graduate           Yes
# 3  LP001006   Male      1.0          0  Not Graduate            No
# 4  LP001008   Male      0.0          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
total_nan = df1.isna().sum().sum()
print(total_nan)
# Out:
# 127

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    float64
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(5), int32(1), int64(1), object(6)
# memory usage: 60.1+ KB

# %%
df1["Gender"] = df1["Gender"].ffill()

# %%
df1["Married"] = df1["Married"].ffill()

# %%
print(df1["Dependents"].unique())
# Out:
# ['0' '1' '2' '3+' nan]

# %%
df1['Dependents'] = df1['Dependents'].replace({'3+': 3})

# %%
df1["Dependents"] = df1["Dependents"].ffill()

# %%
print(df1["Dependents"].unique())
# Out:
# ['0' '1' '2' 3]

# %%
df1["Dependents"] = df1["Dependents"].astype(int)

# %%
df1["Self_Employed"] = df1["Self_Employed"].ffill()

# %%
df1['Loan_Amount_Term'] = df1['Loan_Amount_Term'].fillna(df1['Loan_Amount_Term'].mean())

# %%
df1["Credit_History"] = df1["Credit_History"].ffill()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    float64
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(5), int32(1), int64(1), object(6)
# memory usage: 60.1+ KB

# %%
df1.head()
# Out:
#     Loan_ID Gender  Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      0.0           0      Graduate            No
# 1  LP001003   Male      1.0           1      Graduate            No
# 2  LP001005   Male      1.0           0      Graduate           Yes
# 3  LP001006   Male      1.0           0  Not Graduate            No
# 4  LP001008   Male      0.0           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df = df1.drop('Loan_ID', axis=1)

# %%
df.head()
# Out:
#   Gender  Married  Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      0.0           0      Graduate            No             5849
# 1   Male      1.0           1      Graduate            No             4583
# 2   Male      1.0           0      Graduate           Yes             3000
# 3   Male      1.0           0  Not Graduate            No             2583
# 4   Male      0.0           0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# ...

# %%
df['Gender'] = df['Gender'].replace({'Male': 1, 'Female': 0})

# %%
print(df["Education"].unique())
# Out:
# ['Graduate' 'Not Graduate']

# %%
df['Education'] = df['Education'].replace({'Graduate': 1, 'Not Graduate': 0})

# %%
df['Self_Employed'] = df['Self_Employed'].replace({'Yes': 1, 'No': 0})

# %%
df['Loan_Status'] = df['Loan_Status'].replace({'Y': 1, 'N': 0})

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1      0.0           0          1              0             5849
# 1       1      1.0           1          1              0             4583
# 2       1      1.0           0          1              1             3000
# 3       1      1.0           0          0              0             2583
# 4       1      0.0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#   Property_Area  Loan_Status
# 0         Urban            1
# 1         Rural            0
# ...

# %%
print(df["Property_Area"].unique())
# Out:
# ['Urban' 'Rural' 'Semiurban']

# %%
df['Property_Area'] = df['Property_Area'].replace({'Urban': 0, 'Rural': 1, 'Semiurban': 2})

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1      0.0           0          1              0             5849
# 1       1      1.0           1          1              0             4583
# 2       1      1.0           0          1              1             3000
# 3       1      1.0           0          0              0             2583
# 4       1      0.0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              1            0
# ...

# %%
df1["Credit_History"] = df1["Credit_History"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    float64
#  2   Dependents         614 non-null    int32
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    float64
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(5), int32(1), int64(6)
# memory usage: 55.3 KB

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1      0.0           0          1              0             5849
# 1       1      1.0           1          1              0             4583
# 2       1      1.0           0          1              1             3000
# 3       1      1.0           0          0              0             2583
# 4       1      0.0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              1            0
# ...

# %%
df["Married"] = df["Married"].astype(int)

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          1              0             5849
# 1       1        1           1          1              0             4583
# 2       1        1           0          1              1             3000
# 3       1        1           0          0              0             2583
# 4       1        0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              1            0
# ...

# %%
df["Credit_History"] = df["Credit_History"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             614 non-null    int64
#  1   Married            614 non-null    int32
#  2   Dependents         614 non-null    int32
#  3   Education          614 non-null    int64
#  4   Self_Employed      614 non-null    int64
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         614 non-null    float64
#  8   Loan_Amount_Term   614 non-null    float64
#  9   Credit_History     614 non-null    int32
#  10  Property_Area      614 non-null    int64
#  11  Loan_Status        614 non-null    int64
# dtypes: float64(3), int32(3), int64(6)
# memory usage: 50.5 KB

# %%
df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0           0          1              0             5849
# 1       1        1           1          1              0             4583
# 2       1        1           0          1              1             3000
# 3       1        1           0          0              0             2583
# 4       1        0           0          1              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0               1
# 1             1508.0  128.000000             360.0               1
# 2                0.0   66.000000             360.0               1
# 3             2358.0  120.000000             360.0               1
# 4                0.0  141.000000             360.0               1
#
#    Property_Area  Loan_Status
# 0              0            1
# 1              1            0
# ...

# %%
df.to_csv('output1.csv', index=True)
